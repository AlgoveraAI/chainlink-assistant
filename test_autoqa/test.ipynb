# %%
from dotenv import load_dotenv
load_dotenv("/home/marshath/play/chainlink/algovate/.env")


from pathlib import Path
from algovate.autoq.autoq import AutoQ
# Out:
# Python-dotenv could not parse statement starting at line 4

# %%
autoq = AutoQ(document_store="/home/marshath/play/chainlink/algovate/algovate/data/documents.pkl")
# Out:
# AutoQ initialized
# AutoQ initialized
# ...

# %%
autoq.generate_eval_pairs(2)
# Out:
# Generating 2 pairs
# Generating 2 pairs
# Generated 1 of 2 pairs
# Generated 1 of 2 pairs
# Generated 2 of 2 pairs
# Generated 2 of 2 pairs

# %%
autoq.pairs
# Out:
# [[{'question': 'What is the purpose of using two data feeds in this context?',
#    'answer': 'To derive the pair that you need, for example, if you needed a BTC/EUR price, you could take the BTC/USD feed and the EUR/USD feed and derive BTC/EUR using division.',
#    'metadata': {'source': 'https://docs.chain.link/data-feeds/examples/'}}],
#  [{'question': 'What is the purpose of the `getAccountInfo` function?',
#    'answer': 'To provide information about the specific target address, including the last time it was topped up.',
#    'metadata': {'source': 'https://docs.chain.link/chainlink-automation/utility-contracts/'}}]]
