# %%
from dotenv import load_dotenv
load_dotenv("/home/marshath/play/chainlink/algovate/.env")

import logging
logging.basicConfig(level=logging.DEBUG)
logger = logging.getLogger(__name__)

# %%
import pickle

from langchain.text_splitter import TokenTextSplitter, RecursiveCharacterTextSplitter
from langchain.chains import RetrievalQA
from langchain.chat_models import ChatOpenAI
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import FAISS

from IPython.display import display, Markdown, Latex

# %%
with open("/home/marshath/play/chainlink/algovate/algovate/data/documents.pkl", "rb") as f:
    documents = pickle.load(f)


splitter = RecursiveCharacterTextSplitter(chunk_size=1500, chunk_overlap=50)
documents = splitter.split_documents(documents)

vectorstore = FAISS.from_documents(documents, embedding=OpenAIEmbeddings())

retriever = vectorstore.as_retriever()
# Out:
# DEBUG:openai:message='Request to OpenAI API' method=post path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings
# ...

# %%
res = retriever.get_relevant_documents("give me a sample solidity contract to use Chainlink price feeds?")
# Out:
# DEBUG:openai:message='Request to OpenAI API' method=post path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings
# DEBUG:openai:api_version=None data='{"input": ["give me a sample solidity contract to use Chainlink price feeds?"], "encoding_format": "base64"}' message='Post details'
# DEBUG:urllib3.connectionpool:https://api.openai.com:443 "POST /v1/engines/text-embedding-ada-002/embeddings HTTP/1.1" 200 None
# DEBUG:openai:message='OpenAI API response' path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings processing_ms=442 request_id=33f05ccc221abc9d63f199b36be29516 response_code=200

# %%
# Markdown(res[0].page_content)

# %%
res1 = retriever.get_relevant_documents("give me a sample solidity contract to use Chainlink VRF?")
# Out:
# DEBUG:openai:message='Request to OpenAI API' method=post path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings
# DEBUG:openai:api_version=None data='{"input": ["give me a sample solidity contract to use Chainlink VRF?"], "encoding_format": "base64"}' message='Post details'
# DEBUG:urllib3.connectionpool:https://api.openai.com:443 "POST /v1/engines/text-embedding-ada-002/embeddings HTTP/1.1" 200 None
# DEBUG:openai:message='OpenAI API response' path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings processing_ms=149 request_id=a52f1c3e08f27ad56e921603e5e0a305 response_code=200

# %%
# Markdown(res1[3].page_content)

# %%
res2 = retriever.get_relevant_documents("give me a sample solidity contract to use NFT Floor Price Feeds?")
# Out:
# DEBUG:openai:message='Request to OpenAI API' method=post path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings
# DEBUG:openai:api_version=None data='{"input": ["give me a sample solidity contract to use NFT Floor Price Feeds?"], "encoding_format": "base64"}' message='Post details'
# DEBUG:urllib3.connectionpool:https://api.openai.com:443 "POST /v1/engines/text-embedding-ada-002/embeddings HTTP/1.1" 200 None
# DEBUG:openai:message='OpenAI API response' path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings processing_ms=326 request_id=00da0105de51edd5f99ef8591ed96be4 response_code=200

# %%
# Markdown(res2[1].page_content)

# %%
res3 = retriever.get_relevant_documents("give me a sample solidity contract to use Proof of Reserve Feeds?")
# Out:
# DEBUG:openai:message='Request to OpenAI API' method=post path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings
# DEBUG:openai:api_version=None data='{"input": ["give me a sample solidity contract to use Proof of Reserve Feeds?"], "encoding_format": "base64"}' message='Post details'
# DEBUG:urllib3.connectionpool:https://api.openai.com:443 "POST /v1/engines/text-embedding-ada-002/embeddings HTTP/1.1" 200 None
# DEBUG:openai:message='OpenAI API response' path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings processing_ms=162 request_id=6be89348ed500f40a28727717c2253b2 response_code=200

# %%
# Markdown(res3[2].page_content)

# %%
res4 = retriever.get_relevant_documents("Give sample code for an example contract that obtains the latest price answer from the BTC / USD feed on the Sepolia testnet?")
# Out:
# DEBUG:openai:message='Request to OpenAI API' method=post path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings
# DEBUG:openai:api_version=None data='{"input": ["Give sample code for an example contract that obtains the latest price answer from the BTC / USD feed on the Sepolia testnet?"], "encoding_format": "base64"}' message='Post details'
# DEBUG:urllib3.connectionpool:https://api.openai.com:443 "POST /v1/engines/text-embedding-ada-002/embeddings HTTP/1.1" 200 None
# DEBUG:openai:message='OpenAI API response' path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings processing_ms=21 request_id=927474af50d2911a542c2bbfc2964f70 response_code=200

# %%
# Markdown(res4[3].page_content)

# %%
res5 = retriever.get_relevant_documents("Give code examples to demonstrate how to deploy a consumer contract on-chain that reads a data feed and stores the value?")
# Out:
# DEBUG:openai:message='Request to OpenAI API' method=post path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings
# DEBUG:openai:api_version=None data='{"input": ["Give code examples to demonstrate how to deploy a consumer contract on-chain that reads a data feed and stores the value?"], "encoding_format": "base64"}' message='Post details'
# DEBUG:urllib3.connectionpool:https://api.openai.com:443 "POST /v1/engines/text-embedding-ada-002/embeddings HTTP/1.1" 200 None
# DEBUG:openai:message='OpenAI API response' path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings processing_ms=26 request_id=f97f0089847ac3ff42cdf884a4bf1b5e response_code=200

# %%
# Markdown(res5[3].page_content)

# %%
res6 = retriever.get_relevant_documents("Write code to show how to use web3.js to retrieve feed data from a price feed?")
# Out:
# DEBUG:openai:message='Request to OpenAI API' method=post path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings
# DEBUG:openai:api_version=None data='{"input": ["Write code to show how to use web3.js to retrieve feed data from a price feed?"], "encoding_format": "base64"}' message='Post details'
# DEBUG:urllib3.connectionpool:https://api.openai.com:443 "POST /v1/engines/text-embedding-ada-002/embeddings HTTP/1.1" 200 None
# DEBUG:openai:message='OpenAI API response' path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings processing_ms=200 request_id=712192c2187ae841362661cc58856c77 response_code=200

# %%
# Markdown(res6[3].page_content)

# %%
res7 = retriever.get_relevant_documents("What is the LINK token contract on ethereum mainnet?")
# Out:
# DEBUG:openai:message='Request to OpenAI API' method=post path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings
# DEBUG:openai:api_version=None data='{"input": ["What is the LINK token contract on ethereum mainnet?"], "encoding_format": "base64"}' message='Post details'
# DEBUG:urllib3.connectionpool:https://api.openai.com:443 "POST /v1/engines/text-embedding-ada-002/embeddings HTTP/1.1" 200 None
# DEBUG:openai:message='OpenAI API response' path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings processing_ms=52 request_id=8471091ba43bea6e01f6893c187a43ca response_code=200

# %%
# Markdown(res7[1].page_content)

# %%
res8 = retriever.get_relevant_documents("What is the chainlink price feed address for 1INCH / ETH?")
# Out:
# DEBUG:openai:message='Request to OpenAI API' method=post path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings
# DEBUG:openai:api_version=None data='{"input": ["What is the chainlink price feed address for 1INCH / ETH?"], "encoding_format": "base64"}' message='Post details'
# DEBUG:urllib3.connectionpool:https://api.openai.com:443 "POST /v1/engines/text-embedding-ada-002/embeddings HTTP/1.1" 200 None
# DEBUG:openai:message='OpenAI API response' path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings processing_ms=101 request_id=64c0e1901cfad719b925089377e0b6bf response_code=200

# %%
# Markdown(res8[3].page_content)

# %%
res9 = retriever.get_relevant_documents("What is the proof of reserve address for CacheGold PoR USD on Goerli Testnet?")
# Out:
# DEBUG:openai:message='Request to OpenAI API' method=post path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings
# DEBUG:openai:api_version=None data='{"input": ["What is the proof of reserve address for CacheGold PoR USD on Goerli Testnet?"], "encoding_format": "base64"}' message='Post details'
# DEBUG:urllib3.connectionpool:https://api.openai.com:443 "POST /v1/engines/text-embedding-ada-002/embeddings HTTP/1.1" 200 None
# DEBUG:openai:message='OpenAI API response' path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings processing_ms=25 request_id=8f73f384578e601c1372c27938ca64d5 response_code=200

# %%
Markdown(res9[3].page_content)
# Out:
# | 🔵HBTC PoR                                 | 1e-7%       |      259200 |    18 | 0x0A8cD0115B1EE87EbA5b8E06A9a15ED93e230f7aAsset name:BTCReserve type:Cross-chainData source:Cross-chainAttestation:Wallet Address Manager                       |
# | ⚫PAX / RESERVES                           | 2%          |       86400 |     8 | 0xf482Ed35406933F321f293aC0e4c6c8f59a22fA5Asset name:US Dollar (USD)Reserve type:Off-chainData source:SelfAttestation:Self-attested                             |
# | ⚫PAXG / RESERVES                          | 2%          |       86400 |     8 | 0x716BB8c60D409e54b8Fb5C4f6aBC50E794DA048aAsset name:Gold in troy ounces (oz t)Reserve type:Off-chainData source:SelfAttestation:Self-attested                  |
# | 🔵Swell ETH PoR                            | 2%          |       86400 |    18 | 0x60cbE8D88EF519cF3C62414D76f50818D211fea1Asset name:Staked ETHReserve type:Cross-chainData source:Beacon Chain / Cross-chainAttestation:Wallet Address Manager |
# ...

# %%
res10 = retriever.get_relevant_documents("What is the rate and Volatility Feed Address for 30-Day ETH APR?")
# Out:
# DEBUG:openai:message='Request to OpenAI API' method=post path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings
# DEBUG:openai:api_version=None data='{"input": ["What is the rate and Volatility Feed Address for 30-Day ETH APR?"], "encoding_format": "base64"}' message='Post details'
# DEBUG:urllib3.connectionpool:https://api.openai.com:443 "POST /v1/engines/text-embedding-ada-002/embeddings HTTP/1.1" 200 None
# DEBUG:openai:message='OpenAI API response' path=https://api.openai.com/v1/engines/text-embedding-ada-002/embeddings processing_ms=191 request_id=cbac9f301f86875284be1e91bab2e25a response_code=200

# %%
Markdown(res10[3].page_content)
# Out:
# | ETH-USD 24hr Realized Volatility         |     nan |    nan | 50%         | 3600s       |     5 | 0x31D04174D0e1643963b38d87f26b0675Bb7dC96e |
# | ETH-USD 30-Day Realized Volatility       |     nan |    nan | 50%         | 3600s       |     5 | 0x8e604308BD61d975bc6aE7903747785Db7dE97e2 |
# | ETH-USD 7-Day Realized Volatility        |     nan |    nan | 50%         | 3600s       |     5 | 0xF3140662cE17fDee0A6675F9a511aDbc4f394003 |
# | LINK-USD 24hr Realized Volatility        |     nan |    nan | 50%         | 3600s       |     5 | 0xfD59B51F25E0Ab790a4F0c483BaC194FA0479D29 |
# | LINK-USD 30-Day Realized Volatility      |     nan |    nan | 50%         | 3600s       |     5 | 0xd599cEF88Bbd27F1392A544bD0F343ec8893124C |
# | LINK-USD 7-Day Realized Volatility       |     nan |    nan | 50%         | 3600s       |     5 | 0x03121C1a9e6b88f56b27aF5cc065ee1FaF3CB4A9 |
# caution
